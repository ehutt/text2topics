# %% [markdown]
# # text2topics example

# %%
import nltk
import spacy
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#import source files
import sys
sys.path.append('../source/')
import corpus
import lda 
import clusters
from iterate import Elbow
from run import word_cloud
source_path = sys.path.pop()

# %%
##### ONLY RUN IF FIRST TIME #####
spacy.cli.download('en')
nltk.download('punkt')

# %% [markdown]
# ## Load data

# %%
clean_path = '../data/'
results_folder = '../results/'
raw_file = clean_path+'raw_docs.pkl'

# %% [markdown]
# ### load pre-cleaned data and word embeddings:

# %%
#load already cleaned data
clean_corpus = corpus.load_clean_corpus(clean_path)
# Out:
# Loaded clean docs.
# Loaded corpus vectors.

# %% [markdown]
# ## Iterate over different number of topics

# %%
start = 2 
stop = 30 
step = 2
elbow = Elbow(start, stop, step, results_folder)
elbow.elbow_kmeans_ch(clean_corpus)
# Out:
# Iterating kmeans over range of topics...
# Saved elbow curve.

# %% [markdown]
# ## Choose best number of topics

# %%
num_topics = 10
cluster_model,top_words_kmeans = clusters.get_kmeans(clean_corpus,num_topics)

# %% [markdown]
# ## Investigate results

# %%
word_cloud(top_words_kmeans,results_folder,show=True)
